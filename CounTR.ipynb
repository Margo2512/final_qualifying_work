# %%
# !git clone https://github.com/Verg-Avesta/CounTR.git
# Out:
# Cloning into 'CounTR'...
# remote: Enumerating objects: 269, done.
# remote: Counting objects: 100% (191/191), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 269 (delta 110), reused 165 (delta 90), pack-reused 78 (from 1)
# Receiving objects: 100% (269/269), 19.93 MiB | 17.78 MiB/s, done.
# Resolving deltas: 100% (151/151), done.

# %%
# !pip install -r /content/CounTR/requirements.txt --upgrade --force-reinstall
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 819.6 kB/s eta 0:00:00
# ERROR: Ignored the following yanked versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.15.0
# ERROR: Could not find a version that satisfies the requirement torchvision==0.14.1+cu116 (from versions: 0.1.6, 0.2.0, 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.16.2, 0.17.0, 0.17.1, 0.17.2, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 0.20.0, 0.20.1, 0.21.0)
# ERROR: No matching distribution found for torchvision==0.14.1+cu116

# %%
# !pip install torch==1.10.0+cu111 torchvision==0.11.0+cu111 torchaudio==0.10.0 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install timm==0.4.9 #0.3.2
# !pip install numpy
# !pip install matplotlib tqdm
# !pip install tensorboard
# !pip install scipy
# !pip install imgaug
# !pip install opencv-python
# !pip3 install hub
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %% [markdown]
# Изменить в файле /content/CounTR/util/misc.py from torch._six import inf на inf = float('inf')

# %% [markdown]
# Изменить в файле /content/CounTR/util/pos_embed.py omega = np.arange(embed_dim // 2, dtype=np.float) на omega = np.arange(embed_dim // 2, dtype=float)

# %%
with open('/usr/local/lib/python3.11/dist-packages/timm/models/layers/helpers.py', 'r') as f:
  text = f.read()

# %%
print(text)
# Out:
# """ Layer/Module Helpers
#
# Hacked together by / Copyright 2020 Ross Wightman
# """
# from itertools import repeat
# import collections.abc
#
#
# # From PyTorch internals
# def _ntuple(n):
#     def parse(x):
#         if isinstance(x, collections.abc.Iterable):
#             return x
#         return tuple(repeat(x, n))
#     return parse
#
#
# to_1tuple = _ntuple(1)
# to_2tuple = _ntuple(2)
# to_3tuple = _ntuple(3)
# to_4tuple = _ntuple(4)
# to_ntuple = _ntuple
#
#
# def make_divisible(v, divisor=8, min_value=None, round_limit=.9):
#     min_value = min_value or divisor
#     new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
#     # Make sure that round down does not go down by more than 10%.
#     if new_v < round_limit * v:
#         new_v += divisor
#     return new_v

# %%
# !python /content/CounTR/demo_zero.py --input_path /content/пузыри.jpg

# %%
# !python /content/CounTR/demo_zero.py --input_path frames/ --output_path results/
# Out:
# Кадры сохранены в frames (100 кадров).
# Средний вектор перемещения объектов: (-1.49, 7.02)
# FPS: 5.52
# ...

# %%
# !python /content/CounTR/demo_zero.py --input_path frames/ --output_path results/
# Out:
# ✅ Кадры сохранены в frames (100 кадров).
# 📌 Средний вектор перемещения объектов: (-1.49, 7.02)
# ...

# %%
# !python /content/CounTR/demo_zero.py --input_path /content/drive/MyDrive/Проекты/Отслеживание_в_реальном_времени/Sort+other_methods_time/PseCo/input_yolov5.mp4 --output_path results
